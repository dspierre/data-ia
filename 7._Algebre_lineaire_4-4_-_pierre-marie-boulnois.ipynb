# %% [markdown]
# # Rappels d'algèbre linéaire - 4/4

# %% [markdown]
# L'objectif de ce TP est de découvrir ou revoir les bases de l'algèbre linéaire utiles pour la compréhension des modèles de machine learning.
#
# Ce Tp est consacré au calcul matriciel. L'objectif est de définir ce qu'est une matrice, les opérations matricielles, les différents types de matrices ainsi que la factorisation matricielle.

# %% [markdown]
# Afin de comprendre de façon intuitive ces notions, nous vous proposons de regarder la série de vidéos de 3Blue1Brown conscrée à l'algèbre linéaire et disponible ici : https://www.youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab
#
# Nous vous proposons également de regarder la série de vidéos de Khan Academy francophone sur l'algèbre linéaire :
# https://fr.khanacademy.org/math/linear-algebra

# %% [markdown]
# ## 1. Veille théorique

# %% [markdown]
# **1. Rappel : quelles sont les opérations matricielles usuelles?**

# %% [markdown]
#  Nous avons comme opération usuelle Addition,soustraction ,multiplication par un scalaire,il y  a aussi la  transpositionde matrice, Multiplication des matrices.
#  1.pour l'addition de  matrice on additionne le nombre de la colone par le nombre de l'autre matrice etc...
#
#  2.La transposée AT (aussi notée A') d'une matrice A est la matrice obtenue en échangeant les lignes et les colonnes de A.
#
#  3.multiplication par un scalaire:Chaque terme de la matrice est multiplié par le nombre:
#
#  4.La transposée AT (aussi notée A') d'une matrice A est la matrice obtenue en échangeant les lignes et les colonnes de A:
#
#  5 Le produit matriciel est :
# associatif : ABC = (AB)C = A(BC)
# distributif par rapport à l'addition : A(B + C) = AB + AC
# non commutatif : AB n'est pas égal à BA en général.
# La matrice unité I est élément neutre pour la multiplication : AIm = InA = A, si la matrice A est de dimensions n × m.
# Transposée d'un produit : (AB)T = BTAT (Attention au changement d'ordre !).

# %% [markdown]
# **2. Définir mathématiquement la Transposée d'une matrice.**

# %% [markdown]
#  Transposée d'une matrice.
#  transposée AT (aussi notée A') d'une matrice A est la matrice obtenue en échangeant les lignes et les colonnes de A :

# %% [markdown]
# **3. Définir mathématiquement l'Inverse d'une matrice.**

# %% [markdown]
# **4. Définir mathématiquement la Trace d'une matrice.**

# %%
Pour une matrice carrée M, sa trace est la somme de ses coefficients diagonaux, notée Tr(M).
La trace de A est la somme des « éléments diagonaux » de A (les éléments de sa diagonale principale).

# %% [markdown]
# **5. Définir mathématiquement une Matrice symétrique.**

# %% [markdown]
#   une matrice symétrique est une matrice carrée qui est égale à sa propre transposée,
#   c'est-à-dire telle que ai,j = aj,i pour tous i et j compris entre 1 et n, où les ai,j
#   s ont les coefficients de la matrice et n est son ordre

# %% [markdown]
# **6. Définir mathématiquement une Matrice semi positive.**

# %% [markdown]
# matrice réelle symétrique M d'ordre n est positive (ou semi-définie positive)
# si elle vérifie l'une des propriétés équivalentes suivantes :
#
# 1.M est un élément positif (en) de la C*-algèbre réelle Mn,n(ℝ), c'est-à-dire que son spectre est inclus dans ℝ+.
#
# 2.La forme bilinéaire symétrique associée à M est positive : pour toute matrice colonne x à n éléments réels, xTMx ≥ 0 (où xT désigne la matrice transposée de )x.
#
# 3.Les valeurs propres de M (qui sont nécessairement réelles) sont positives ou nulles.
#
# 4.Il existe une matrice réelle N telle que M = NTN.
#
# 5.Tous les mineurs principaux2 de M sont positifs ou nuls : pour toute partie non vide I de {1, … , n}, le déterminant de la sous-matrice MI,I de M (formée de ses éléments avec indices de lignes et de colonnes dans I) est positif ou nul.
# *les mineurs d'une matrice sont les déterminants de ses sous-matrices carrées.

# %% [markdown]
# **7. Définir mathématiquement le Déterminant d'une matrice.**

# %% [markdown]
# ## 2. Codage en Python

# %% [markdown]
# **1. Faire la somme des matrices $$A = \begin{bmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \end{bmatrix}$$ et $$B = \begin{bmatrix} 4 & 5 & 6 \\ 1 & 2 & 3 \end{bmatrix}$$**

# %% [markdown]
# **2. Affichez les dimensions de `A` et `B`.**

# %%
 import numpy as np
A = np.array([[1, 2,3], [4, 5,6]])
B = np.array([[4, 5,6], [1, 2,3]])
C=A+B
print(C)
# Out:
# [[5 7 9]
#  [5 7 9]]

# %%
print(A.shape,B.shape)
# Out:
# (3, 5) (2, 3)

# %% [markdown]
# **3. Effectuer le produit des matrices `A` et `B`.**

# %%
import numpy as np
a= np.array([[1, 2, 3],
            [4, 5, 6]])
b = np.array([[2, 1, 3],
            [3, 2, 1]])
print(a*b)
# Out:
# [[ 2  2  9]
#  [12 10  6]]

# %% [markdown]
# **4. Reprendre l'image précédente et une nouvelle image d'un rond. Additionner ces deux images (vérifier au préalable leurs dimensions)**

# %%
plt.imshow(image)
plt.show()

# %%
import matplotlib.image as mpimg
from scipy import misc

image = misc.face(gray=True)
# affichage de la matrice
print(image)
# affichage de l'image
plt.imshow(image)
# Chargement de l'image du rond
image1 = mpimg.imread('rond.jpg')
plt.imshow(image1)

# afficher les tailles 
print(np.shape(image))
print(np.shape(image1))

# choix d'arnaud agrandir le rond 
image1 = np.resize(image1,np.shape(image))
image_finale = image+image1
print(image_finale)
plt.imshow(image_finale)
plt.show()
# Out:
# [[114 130 145 ... 119 129 137]
#  [ 83 104 123 ... 118 134 146]
#  [ 68  88 109 ... 119 134 145]
#  ...
#  [ 98 103 116 ... 144 143 143]
#  [ 94 104 120 ... 143 142 142]
#  [ 94 106 119 ... 142 141 140]]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-40-40a631fb96f8> in <module>
#       8 plt.imshow(image)
#       9 # Chargement de l'image du rond
# ---> 10 image1 = mpimg.imread('https://cdn.discordapp.com/attachments/686300300356616274/690129292922978327/rond.jpg')
#      11 plt.imshow(image1)
#      12
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1428         if len(parsed.scheme) > 1:
#    1429             from urllib import request
# -> 1430             fd = BytesIO(request.urlopen(fname).read())
#    1431             return handler(fd)
#    1432         else:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# ## 3. Règle de Cramer - Résolution de systèmes d'équations
# Si on considère un système de n équations à n inconnues équivalent à AX = B.
#
# D'après la règle de Cramer, si la matrice A est inversible (son déterminant est différent de 0), le sytème admet une unique solution donnée par :
#
# $ x_{k}={\det(A_{k}) \over \det(A)} $
#
# $ A_k $ est la matrice carrée formée en remplaçant la k-ième colonne de A  par le vecteur colonne B

# %% [markdown]
# ## 4. Codage en Python

# %% [markdown]
#  **1. Soit $$A = \begin{bmatrix} 1 & 2 & 3 \\ 0 & 1 & 4 \\ 5 & 6 & 0\end{bmatrix}$$
#     Calculer la transposée de A, sa trace et son déterminant et son inverse.**

# %%
#transposé d'une matrice
A = np.array([[1, 2,3], [0, 1,4],[5, 6,0]])
A.T
print(A.T)
# Out:
# [[1 0 5]
#  [2 1 6]
#  [3 4 0]]

# %%
#trace d'une matrice
print(np.trace(A))
# Out:
# 2

# %%
#detérminant  d'une  matrice 
np.linalg.det(A)
# Out:
# 0.9999999999999987

# %%
A_inv = np.linalg.inv(A)
print(A_inv)
# Out:
# [[-24.  18.   5.]
#  [ 20. -15.  -4.]
#  [ -5.   4.   1.]]

# %% [markdown]
# **2. En reprenant l'image précédente, afficher l'image puis sa transposée.**

# %%
#Chargement d'une image
from scipy import misc
import matplotlib.pyplot as plt
image = misc.face(gray=True)
plt.imshow(image)
plt.show()
print(image)
# Out:
# [[114 130 145 ... 119 129 137]
#  [ 83 104 123 ... 118 134 146]
#  [ 68  88 109 ... 119 134 145]
#  ...
#  [ 98 103 116 ... 144 143 143]
#  [ 94 104 120 ... 143 142 142]
#  [ 94 106 119 ... 142 141 140]]

# %%
from scipy import misc
import matplotlib.pyplot as plt
image_T=transpose(image)
plt.imshow(image_T)

# %% [markdown]
#  **3. On considère le système d'équations suivant :**
#
#   **2x + y = 12**
#
#   **x + 3y = 8**
#
# **Déterminer la matrice A résultante et calculer les solutions du système en utilisant la règle de Cramer. Comparer avec les solutions obtenues avec la fonction linalg.solve de la librairie Numpy**

# %%
from numpy import *

A=matrix([[2,1],[1,3]])
B=matrix([[12],[8]])
solution=linalg.solve(A,B)
print(solution)
# Out:
# [[5.6]
#  [0.8]]

# %%
from fractions import *
A=matrix([[2,1],[1,3]])
det_A=np.linalg.det(A)
print(det_A)
# Out:
# 5.000000000000001

# %%
A = np.array([[2,12],[1,8]])
print(A)
# Out:
# [[ 2 12]
#  [ 1  8]]

# %%
A1 = np.array([[2,8],[1,12]])
A2 = np.array([[2,1],[12,8]])
x1=np.linalg.det(A1)/det_A
x2=np.linalg.det(A2)/det_A
print(x1)
print(x2)
# Out:
# 3.1999999999999993
# 0.7999999999999997

# %% [markdown]
# ## 4. Matrices denses et creuses
#
# Une matrice creuse ("sparse") est une matrice qui comporte un grand nombre d'élements nuls. A l'inverse, une matrice dense comporte surtout des données non nulles.
# Le "degré" de sparsité de la matrice peut être évalué en mesurant la proportion d'élements nuls contenus dans la matrice par rapport au nombre total d'éléments.
#
# De telles matrices,présentant des éléments vides d'information, sont coûteuses en termes de mémoire allouée pour leur stockage. L'ordre de complexité pour effectuer des opérations matricielles (ex: calcul d'inverse) tend à également s'accroître avec des matrices sparse.
#
# Le problème de sparsité des données est courant dans les big data. Plus généralement, en matière de machine learning, on est très souvent confronté à des matrices creuses, notamment dans les domaines du traitement du langage naturel (NLP - construction de vecteurs de mots de grande dimension comportant beaucoup de valeurs nulles), les systèmes de recommendation (ex : matrice utilisateurs - films très creuse) et le computing vision (ex: images comportant beaucoup de pixels noirs - valeurs à zéro).
#
# Pour pallier à ce problème, il est possible d'utiliser de nouvelles représentations des données en entrée comme celles obtenues après compression (ex : méthode CSR - "Compressed Sparse Row" - pour convertir un matrice dense en matrice creuse).

# %% [markdown]
# ## 5. Codage en Python

# %% [markdown]
# **1. On considère la matrice suivante :**
#
# $$A = \begin{bmatrix} 1 & 0 & 0 & 0 & 2 \\ 0 & 0 & 4 & 1 & 5 \\ 5 & 6 & 0 & 0 & 0\end{bmatrix}$$
#
# **Créer la matrice A.**
#
#
# **Afficher le degré de sparsité (proportion du nombre de 0) de cette matrice.**
#
# **Convertir cette matrice en sparse matrice en utilisant la méthode CSR de la librairie Numpy.**
#
# **Afficher la matrice issue de cette conversion puis la reconvertir en matrice dense.**

# %%
A = np.array([[1, 0,0,0,2],[0, 0,4,1,5],[5, 6,0,0,0]])
print(A)
# Out:
# [[1 0 0 0 2]
#  [0 0 4 1 5]
#  [5 6 0 0 0]]

# %%
print(np.size(A))
# Out:
# 15

# %%
from scypy import sparse
A_=sparse.car_matrix(A)
print(A_)
print(A)

# %%
 from scipy import sparse
print('sparcite=',round(str(A).count/np.size(A,2))
# Out:
#   File "<ipython-input-87-d72c085c41a7>", line 2
#     print('sparcite=', round(str(A).count/np.size(A,2))
#                                                        ^
# SyntaxError: unexpected EOF while parsing
