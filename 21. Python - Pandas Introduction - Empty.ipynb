# %% [markdown]
# # 21. Python - Pandas Introduction

# %% [markdown]
# <span style="color:red">**NOTE :**</span>
#
# **Avant de commencer le TP, téléchargez les deux dataset (`super_hero_powers` et `heroes_information`) et placez-les dans le dossier où est sauvegardé le notebook.**
#
# **Tutoriels à suivre**
# #### 1)
# https://openclassrooms.com/fr/courses/4452741-decouvrez-les-librairies-python-pour-la-data-science/5558996-passez-de-numpy-a-pandas
#
# #### 2)
#
# https://openclassrooms.com/fr/courses/4452741-decouvrez-les-librairies-python-pour-la-data-science/5574866-manipulez-les-donnees-contenues-dans-vos-dataframes

# %% [markdown]
# ### 1. Qu'est ce que pandas?

# %% [markdown]
# Pandas est une bibliothèque écrite pour le langage de programmation
# Python permettant la manipulation et l'analyse des données.
# Elle propose en particulier des structures de données et des opérations
# de manipulation de tableaux numériques et de séries temporelles.
# Pandas est un logiciel libre sous licence BSD2

# %% [markdown]
# ### 2. Importer les libraires `numpy` et `pandas`.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 3. Utilisez la fonctions `read_csv()` de `pandas` pour importer les deux dataset (fichiers csv) au format dataframe.

# %%
import numpy as np
import pandas as pd
pd.read_csv('super_hero_powers.csv')
# Out:
#           hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# ..               ...      ...                  ...                 ...
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# ...

# %%
import numpy as np
import pandas as pd
pd.read_csv('heroes_information.csv')
# Out:
#      Unnamed: 0             name  Gender Eye color               Race  \
# 0             0           A-Bomb    Male    yellow              Human
# 1             1       Abe Sapien    Male      blue      Icthyo Sapien
# 2             2         Abin Sur    Male      blue            Ungaran
# 3             3      Abomination    Male     green  Human / Radiation
# 4             4          Abraxas    Male      blue      Cosmic Entity
# ..          ...              ...     ...       ...                ...
# 729         729  Yellowjacket II  Female      blue              Human
# 730         730             Ymir    Male     white        Frost Giant
# 731         731             Yoda    Male     brown     Yoda's species
# 732         732          Zatanna  Female      blue              Human
# 733         733             Zoom    Male       red                  -
#
#            Hair color  Height          Publisher Skin color Alignment  Weight
# ...

# %% [markdown]
# ### 4. Utilisez la fonction `head` pour afficher les 5 premières lignes des deux datasets.

# %%
import numpy as np
import pandas as pd
# making data frame 
data = pd.read_csv("heroes_information.csv")  
# calling head() method  
# storing in new variable 
data_top = data.head(5)   
# display 
data_top
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
import numpy as np
import pandas as pd
# making data frame 
data = pd.read_csv("super_hero_powers.csv")  
# calling head() method  
# storing in new variable 
data_top = data.head()  
# display 
data_top
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# ...

# %% [markdown]
# ### 5. Affichez la taille des datasets.

# %%
import pandas
df1 = pandas.read_table("super_hero_powers.csv",sep =',',header = 0)
print(df.shape)
# Out:
# (734, 1)

# %%
import pandas
df2 = pandas.read_table("heroes_information.csv",sep =',',header = 0)
print(df.shape)
# Out:
# (734, 1)

# %% [markdown]
# ### 6. Affichez la colonne `name` du dataframe `df_heroes_info` puis affichez son type.

# %%
import pandas
print(data['name'])
# Out:
# 0               A-Bomb
# 1           Abe Sapien
# 2             Abin Sur
# 3          Abomination
# 4              Abraxas
#             ...
# 729    Yellowjacket II
# 730               Ymir
# 731               Yoda
# 732            Zatanna
# 733               Zoom
# Name: name, Length: 734, dtype: object

# %% [markdown]
# ### 7. Affichez la liste des colonnes disponibles dans les deux dataset.

# %%
(df2.columns)
# Out:
# Index([',name,Gender,Eye color,Race,Hair color,Height,Publisher,Skin color,Alignment,Weight'], dtype='object')

# %%
print(df2.columns)
# Out:
# Index([',name,Gender,Eye color,Race,Hair color,Height,Publisher,Skin color,Alignment,Weight'], dtype='object')

# %% [markdown]
# ### 8. Appliquez la méthode `describe` au dataframe `df_heroes_powers` puis au dataframe `df_heroes_info`. A quoi correspond chacune des lignes du tableau obtenu?

# %%
import pandas
df1.describe()
# Out:
#        hero_names Agility Accelerated Healing Lantern Power Ring  \
# count         667     667                 667                667
# unique        667       2                   2                  2
# top     Blackwulf   False               False              False
# freq            1     425                 489                656
#
#        Dimensional Awareness Cold Resistance Durability Stealth  \
# count                    667             667        667     667
# unique                     2               2          2       2
# top                    False           False      False   False
# freq                     642             620        410     541
#
#        Energy Absorption Flight  ... Web Creation Reality Warping Odin Force  \
# count                667    667  ...          667             667        667
# unique                 2      2  ...            2               2          2
# top                False  False  ...        False           False      False
# ...

# %%
import pandas
df2.describe()
# Out:
#        Unnamed: 0      Height      Weight
# count  734.000000  734.000000  732.000000
# mean   366.500000  102.254087   43.855191
# std    212.031837  139.624543  130.823733
# min      0.000000  -99.000000  -99.000000
# 25%    183.250000  -99.000000  -99.000000
# 50%    366.500000  175.000000   62.000000
# 75%    549.750000  185.000000   90.000000
# max    733.000000  975.000000  900.000000

# %% [markdown]
# ### 9. Executez le code suivant. Que fait-il?

# %%
num_powers = df1.sum(axis=0)[1:]
print(num_powers)
# Out:
# Agility                   242
# Accelerated Healing       178
# Lantern Power Ring         11
# Dimensional Awareness      25
# Cold Resistance            47
#                          ...
# Phoenix Force            True
# Molecular Dissipation    True
# Vision - Cryo               2
# Omnipresent                 2
# Omniscient                  2
# Length: 167, dtype: object

# %%
df2.describe()
# Out:
#        Unnamed: 0      Height      Weight
# count  734.000000  734.000000  732.000000
# mean   366.500000  102.254087   43.855191
# std    212.031837  139.624543  130.823733
# min      0.000000  -99.000000  -99.000000
# 25%    183.250000  -99.000000  -99.000000
# 50%    366.500000  175.000000   62.000000
# 75%    549.750000  185.000000   90.000000
# max    733.000000  975.000000  900.000000

# %%
df1.describe()
# Out:
#        hero_names Agility Accelerated Healing Lantern Power Ring  \
# count         667     667                 667                667
# unique        667       2                   2                  2
# top     Blackwulf   False               False              False
# freq            1     425                 489                656
#
#        Dimensional Awareness Cold Resistance Durability Stealth  \
# count                    667             667        667     667
# unique                     2               2          2       2
# top                    False           False      False   False
# freq                     642             620        410     541
#
#        Energy Absorption Flight  ... Web Creation Reality Warping Odin Force  \
# count                667    667  ...          667             667        667
# unique                 2      2  ...            2               2          2
# top                False  False  ...        False           False      False
# ...

# %% [markdown]
# ### 10. En déduire les 10 pouvoirs les plus présents dans les données.

# %%
import pandas
num_powers = num_powers.sort_values(ascending=False)
print(num_powers[0:10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _try_kind_sort(arr)
#    3149                 # if kind==mergesort, it can fail for object dtype
# -> 3150                 return arr.argsort(kind=kind)
#    3151             except TypeError:
#
# TypeError: '<' not supported between instances of 'numpy.ndarray' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-43bbddd6bad8> in <module>
#       1 import pandas
# ----> 2 num_powers = num_powers.sort_values(ascending=False)
#       3 print(num_powers[0:10])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
# ...

# %% [markdown]
# ### 11. Supprimer la colonne `Unnamed: 0` dans le dataframe `df_heroes_info`.

# %%
import pandas
df2 = pandas.read_table("heroes_information.csv",sep =',',header = 0)
print(df2.shape)
# Out:
# (734, 11)

# %% [markdown]
# ### 12. Affichez le pourcentage de femmes présentes dans le jeu de données.

# %%
df2['Gender'].value_counts(normalize=True) * 100
# Out:
# Male      68.801090
# Female    27.247956
# -          3.950954
# Name: Gender, dtype: float64

# %% [markdown]
# ### 13. En utilisant la méthode `crosstab` anamysez la répartition du genre (`Gender`) en fonction du rôle (`Alignment`).

# %%
pandas.crosstab(df2['Gender'],df2['Alignment'])
# Out:
# Alignment  -  bad  good  neutral
# Gender
# -          1    7    19        2
# Female     0   35   161        4
# Male       6  165   316       18
